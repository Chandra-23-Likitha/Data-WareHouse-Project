# %% [markdown]
# ![image_1788245859954.png](./image_1788245859954.png "image_1788245859954.png")

# %% [markdown]
# ![image_1788245880795.png](./image_1788245880795.png "image_1788245880795.png")

# %% [markdown]
# ![image_1788245899975.png](./image_1788245899975.png "image_1788245899975.png")
