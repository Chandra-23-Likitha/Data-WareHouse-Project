# %%
# %sql
CREATE CATALOG IF NOT EXISTS retailworks;
CREATE SCHEMA IF NOT EXISTS retailworks.bronze;
CREATE SCHEMA IF NOT EXISTS retailworks.silver;
CREATE SCHEMA IF NOT EXISTS retailworks.gold;

CREATE VOLUME IF NOT EXISTS  retailworks.bronze.source_files;
